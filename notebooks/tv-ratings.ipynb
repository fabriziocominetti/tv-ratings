# %% [markdown]
# ## **IMDb TV Ratings**

# %%
# imports
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# _IMDb_ | https://datasets.imdbws.com/

# %% [markdown]
# **title.basics.tsv.gz**
#
# - `tconst` (string) - alphanumeric unique identifier of the title
# - `titleType` (string) - the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# - `primaryTitle` (string) - the more popular title / the title used by the filmmakers on promotional materials at the point of release
# - `originalTitle` (string) - original title, in the original language
# - `isAdult` (boolean) - 0: non-adult title; 1: adult title
# - `startYear` (YYYY) - represents the release year of a title. In the case of TV Series, it is the series start year
# - `endYear` (YYYY) - TV Series end year. ‘\N’ for all other title types
# - `runtimeMinutes` - primary runtime of the title, in minutes
# - `genres` (string array) - includes up to three genres associated with the title

# %% [markdown]
# **title.episode.tsv.gz**
#
# - `tconst` (string) - alphanumeric identifier of episode
# - `parentTconst` (string) - alphanumeric identifier of the parent TV Series
# - `seasonNumber` (integer) - season number the episode belongs to
# - `episodeNumber` (integer) - episode number of the tconst in the TV series

# %% [markdown]
# **title.ratings.tsv.gz**
#
# - `tconst` (string) - alphanumeric unique identifier of the title
# - `averageRating` - weighted average of all the individual user ratings
# - `numVotes` - number of votes the title has received

# %%
title_basics = pd.read_csv("../data/title_basics.tsv", sep="\t", low_memory=False)
title_episode = pd.read_csv("../data/title_episode.tsv", sep="\t", low_memory=False)
title_ratings = pd.read_csv("../data/title_ratings.tsv", sep="\t", low_memory=False)

# %%
print(title_basics.shape)
print('')
print(title_basics.columns)
print('')
title_basics.head()
# Out:
# (10702767, 9)
#
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
# convert data types
title_basics['titleType'] = title_basics['titleType'].astype('category')

# %%
# check for null values
title_basics.isna().sum()
# Out:
# tconst              0
# titleType           0
# primaryTitle       18
# originalTitle      18
# isAdult             0
# startYear           0
# endYear             0
# runtimeMinutes      0
# genres            312
# dtype: int64

# %%
title_basics[title_basics.primaryTitle.isna()]
# Out:
#               tconst  titleType primaryTitle originalTitle isAdult startYear  \
# 625849     tt0648118  tvEpisode          NaN           NaN       0      1987
# 1253522   tt10516578      video          NaN           NaN       0      2017
# 3430926   tt14510930  tvEpisode          NaN           NaN       0        \N
# 4073479   tt15700278  tvEpisode          NaN           NaN       0      2021
# 4554578   tt17042812      movie          NaN           NaN       0      2010
# 5062105    tt1971246  tvEpisode          NaN           NaN       0      2011
# 5257752    tt2067043  tvEpisode          NaN           NaN       0      1965
# 5596138   tt21883066  tvEpisode          NaN           NaN       0      2022
# 5865630    tt2305914  tvEpisode          NaN           NaN       0        \N
# 5865637    tt2305918  tvEpisode          NaN           NaN       0        \N
# 7537096   tt31462159  tvEpisode          NaN           NaN       0      2024
# 7767275    tt3383210      short          NaN           NaN       0      2013
# 8808503    tt5746000      short          NaN           NaN       0      2016
# 8820083    tt5773048  tvEpisode          NaN           NaN       0      2015
# 8820526    tt5774076      movie          NaN           NaN       0      2015
# 10040226   tt8473688  tvEpisode          NaN           NaN       0      1987
# 10071260   tt8541336  tvEpisode          NaN           NaN       0      2018
# 10660140   tt9824302  tvEpisode          NaN           NaN       0      2016
#
#          endYear runtimeMinutes                     genres
# 625849        \N             60        Crime,Drama,Mystery
# 1253522       \N             \N                Music,Short
# 3430926       \N             \N                         \N
# 4073479       \N             \N                  Talk-Show
# 4554578       \N             87                   Thriller
# 5062105       \N             \N                  Biography
# 5257752       \N             \N                      Music
# 5596138       \N             \N             News,Talk-Show
# 5865630       \N             \N           Comedy,Talk-Show
# 5865637       \N             \N           Comedy,Talk-Show
# 7537096       \N             \N                      Drama
# 7767275       \N             12  Documentary,History,Short
# 8808503       \N             12                      Short
# 8820083       \N             \N                  Talk-Show
# 8820526       \N             \N       Action,Drama,Mystery
# 10040226      \N             \N                      Drama
# 10071260      \N             30         Reality-TV,Romance
# 10660140      \N             \N                Documentary

# %%
title_basics[title_basics.genres.isna()]
# Out:
#               tconst  titleType  \
# 1096955   tt10233364  tvEpisode
# 1506642   tt10970874  tvEpisode
# 1894071   tt11670006  tvEpisode
# 2004921   tt11868642  tvEpisode
# 2158796   tt12149332  tvEpisode
# ...              ...        ...
# 7692078   tt32124610  tvEpisode
# 7692810   tt32126116  tvEpisode
# 8029026    tt3984412  tvEpisode
# 10659462   tt9822816  tvEpisode
# 10699227   tt9909210  tvEpisode
#
#                                                primaryTitle originalTitle  \
# 1096955   Rolling in the Deep Dish\tRolling in the Deep ...             0
# 1506642   Die Bauhaus-Stadt Tel Aviv - Vorbild für die M...             0
# 1894071   ...ein angenehmer Unbequemer...\t...ein angene...             0
# 2004921   GGN Heavyweight Championship Lungs With Mike T...             0
# 2158796   Jeopardy! College Championship Semifinal Game ...             0
# ...                                                     ...           ...
# 7692078   Godzilla`s Revenge '1969\tGodzilla`s Revenge '...             0
# 7692810   Conquest of the Planet of the Apes\tConquest o...             0
# 8029026   I'm Not Going to Come Last, I'm Just Going to ...             0
# 10659462  Zwischen Vertuschung und Aufklärung - Missbrau...             0
# 10699227  Politik und/oder Moral - Wie weit geht das Ver...             0
#
#          isAdult startYear endYear              runtimeMinutes genres
# 1096955     2019        \N      \N                  Reality-TV    NaN
# 1506642     2019        \N      \N                   Talk-Show    NaN
# 1894071     1981        \N      \N                 Documentary    NaN
# 2004921     2020        \N      \N                   Talk-Show    NaN
# 2158796     2020        \N      \N  Game-Show,Reality-TV,Short    NaN
# ...          ...       ...     ...                         ...    ...
# 7692078     1987        \N      \N      Fantasy,Horror,Mystery    NaN
# 7692810     1987        \N      \N      Fantasy,Horror,Mystery    NaN
# 8029026     2014        \N      \N        Game-Show,Reality-TV    NaN
# 10659462    2019        \N      \N                   Talk-Show    NaN
# 10699227    2005        \N      \N                   Talk-Show    NaN
#
# [312 rows x 9 columns]

# %%
title_basics = title_basics.dropna()

# %%
title_basics['titleType'].cat.categories
# Out:
# Index(['movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvPilot',
#        'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame'],
#       dtype='object')

# %%
print(title_episode.shape)
print('')
print(title_episode.columns)
print('')
title_episode.head()
# Out:
# (8189406, 4)
#
# Index(['tconst', 'parentTconst', 'seasonNumber', 'episodeNumber'], dtype='object')
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0041951    tt0041038            1             9
# 1  tt0042816    tt0989125            1            17
# 2  tt0042889    tt0989125           \N            \N
# 3  tt0043426    tt0040051            3            42
# 4  tt0043631    tt0989125            2            16

# %%
title_episode.dtypes
# Out:
# tconst           object
# parentTconst     object
# seasonNumber     object
# episodeNumber    object
# dtype: object

# %%
# check for null values
title_episode.isna().sum()
# Out:
# tconst           0
# parentTconst     0
# seasonNumber     0
# episodeNumber    0
# dtype: int64

# %%
print(title_ratings.shape)
print('')
print(title_ratings.columns)
print('')
title_ratings.head()
# Out:
# (1427087, 3)
#
# Index(['tconst', 'averageRating', 'numVotes'], dtype='object')
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2043
# 1  tt0000002            5.7       273
# 2  tt0000003            6.5      2001
# 3  tt0000004            5.4       178
# 4  tt0000005            6.2      2760

# %%
title_ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
# check for null values
title_ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
# save to csv
title_basics.to_csv('../data/title_basics.csv', index=False)
title_episode.to_csv('../data/title_episode.csv', index=False)
title_ratings.to_csv('../data/title_ratings.csv', index=False)
